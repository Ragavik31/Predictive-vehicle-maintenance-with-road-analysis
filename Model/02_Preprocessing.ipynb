# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("data/raw/logistics_predictive_maintenanceV2.csv")

df.head()
# Out:
#    Vehicle_ID   Make_and_Model        Vehicle_Type  Year_of_Manufacture  \
# 0           1       Ford F-150  Refrigerated Truck                 2016
# 1           2  Chevy Silverado         Light Truck                 2017
# 2           3          MAN TGX        Medium Truck                 2011
# 3           4  Mercedes Actros      Electric Truck                 2020
# 4           5  Mercedes Actros         Heavy Truck                 2024
#
#          Route_Info Weather_Conditions Road_Conditions  \
# 0   Highway Freight              Humid          Smooth
# 1   Highway Freight              Rainy           Rough
# 2   Highway Freight              Humid       Congested
# 3  Cold-Chain Route              Rainy        Moderate
# 4   Highway Freight              Humid     Mountainous
#
#   Communication_Interface   Telematics_Gateway   Edge_Device_Class  ...  \
# 0                 CAN/LIN       Fleet_IoT_Node      Automotive_ECU  ...
# 1              OBD-II/CAN  Edge_Telematics_Box  NVIDIA_Jetson_Nano  ...
# 2              OBD-II/CAN  Edge_Telematics_Box      ARM_Cortex_A72  ...
# 3       CAN-FD/Telematics       Fleet_IoT_Node      ARM_Cortex_A53  ...
# 4              OBD-II/CAN       Fleet_IoT_Node  NVIDIA_Jetson_Nano  ...
#
#       OHI    CMES      UER  Predictive_Score  Pre_Event_Record  Data_Split  \
# 0  1.5736  1.4739  64.2038            0.1582                 1       Train
# 1  1.4027  2.6860  28.6928            0.1757                 1        Test
# 2  2.2707  1.4311  76.7502            0.2047                 1       Train
# 3  1.0520  1.3057  44.7529            0.1689                 1       Train
# 4  0.2724  3.2195   3.9567            0.1895                 1       Train
#
#    FL_Client_ID               Partition_Type  Local_Epochs_Per_Round  \
# 0             1  Non-IID Dirichlet alpha=0.5                       2
# 1             1  Non-IID Dirichlet alpha=0.5                       2
# 2             2  Non-IID Dirichlet alpha=0.5                       2
# 3             3  Non-IID Dirichlet alpha=0.5                       2
# 4             4  Non-IID Dirichlet alpha=0.5                       2
#
#    Communication_Rounds
# 0                   200
# 1                   200
# 2                   200
# 3                   200
# 4                   200
#
# [5 rows x 50 columns]

# %%
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 250000
# Columns: 50

# %%
df["Last_Maintenance_Date"] = pd.to_datetime(
    df["Last_Maintenance_Date"]
)

# %%
numerical_columns = df.select_dtypes(
    include=["int64","float64"]
).columns.tolist()

categorical_columns = df.select_dtypes(
    include="object"
).columns.tolist()

print("Numerical:", len(numerical_columns))
print("Categorical:", len(categorical_columns))
# Out:
# Numerical: 36
# Categorical: 13
# C:\Users\ragav\AppData\Local\Temp\ipykernel_14104\124758135.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(

# %%
label_encoders = {}

for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))
    label_encoders[col] = le

# %%
df["Maintenance_Required"].value_counts()
df["Maintenance_Required"].value_counts(normalize=True) * 100
# Out:
# Maintenance_Required
# 0    70.0
# 1    30.0
# Name: proportion, dtype: float64

# %%
df.to_csv(
    "data/processed/preprocessed_dataset.csv",
    index=False
)
